# %% [markdown]
# # 2.1.Extraction d'un fichier csv

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd

# %% [markdown]
# ## Extract from CSV file

# %%
brevets = pd.read_csv('/Users/juliensisavath2017/THP_loc/THP-2/S05/1/2.SourceDB/2.1_CSV-Extract/fr-esr-brevets-france-inpi-oeb.csv', sep = ";", encoding = 'utf-8')
brevets
# Out:
#        num_depot origine  annees_publication  annees_delivrance part  \
# 0        1161944  France                2013             2013.0  Non
# 1        0400729  France                2005             2006.0  Non
# 2        0512601  France                2007                NaN  Non
# 3        1150006  France                2012             2014.0  Non
# 4        1101373  France                2012             2014.0  Non
# ...          ...     ...                 ...                ...  ...
# 222622   0402041  France                2005                NaN  Non
# 222623   0402056  France                2005             2007.0  Non
# 222624   1058214  France                2012             2013.0  Non
# 222625   1158228  France                2013             2014.0  Non
# 222626   0402205  France                2005             2006.0  Non
#
#                              type_d_tablissement  num_siren    id_dep  \
# ...

# %% [markdown]
# ## How many Brevets request we have

# %%
len(brevets)
# Out:
# 222627

# %%
len(brevets[brevets['brev_de'].str.startswith('Oui')])
# Out:
# 77705

# %% [markdown]
# ### Based on 222'627 schools, there are 77'705 requests
